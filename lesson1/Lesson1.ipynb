# %%
import numpy as np
import pandas as pa

# %%
# %matplotlib inline

# %%
a = list([1, 2, 3])

# %%
numpy_array = np.array(a)

# %%
numpy_array
# Out:
# array([1, 2, 3])

# %%
np.random.rand(3,4) * 100
# Out:
# array([[ 56.86931821,  25.31999691,  73.80638851,  63.62706287],
#        [ 39.80469065,  17.65948841,  95.3907272 ,  18.14364435],
#        [ 39.49884613,  65.24564151,   1.45012377,  64.90270163]])

# %%
numpy_array.size
# Out:
# 3

# %%
numpy_array.shape
# Out:
# (3,)

# %%
A = np.array([[1, 2], [2, 1]])

# %%
A
# Out:
# array([[1, 2],
#        [2, 1]])

# %%
B = np.array([[2, 4], [8, 16]])

# %%
B
# Out:
# array([[ 2,  4],
#        [ 8, 16]])

# %%
np.dot(A, B)
# Out:
# array([[18, 36],
#        [12, 24]])

# %%
np.sin(A)
# Out:
# array([[ 0.84147098,  0.90929743],
#        [ 0.90929743,  0.84147098]])

# %%
np.savetxt('file1.csv', np.sin(np.dot(A, B)), delimiter=',')

# %%
data = pa.read_csv('Most-Recent-Cohorts-Scorecard-Elements.csv', delimiter=',')

# %%
data
# Out:
#         UNITID     OPEID  OPEID6  \
# 0       100654    100200    1002
# 1       100663    105200    1052
# 2       100690   2503400   25034
# 3       100706    105500    1055
# 4       100724    100500    1005
# 5       100751    105100    1051
# 6       100760    100700    1007
# 7       100812    100800    1008
# 8       100830    831000    8310
# 9       100858    100900    1009
# 10      100937    101200    1012
# 11      101028   1218200   12182
# 12      101073   1055400   10554
# 13      101116   1303906   13039
# 14      101143    101500    1015
# 15      101161    106000    1060
# 16      101189    100300    1003
# 17      101240    101700    1017
# 18      101277   4187200   41872
# 19      101286    101800    1018
# 20      101295    787100    7871
# 21      101301    569900    5699
# 22      101365    962107    9621
# 23      101435    101900    1019
# 24      101453   2199700   21997
# 25      101462    526000    5260
# 26      101480    102000    1020
# ...

# %%
medians = data.median()

# %%
medians.plot()

# %%
data['UNITID'].plot()

# %%
data.describe()
# Out:
#              UNITID         OPEID        OPEID6         HCM2      PREDDEG  \
# count  7.703000e+03  7.703000e+03   7703.000000  7703.000000  7703.000000
# mean   1.663052e+06  1.891630e+06  16293.906530     0.030637     1.799688
# std    6.566910e+06  3.383134e+06  13883.577507     0.172344     1.023986
# min    1.006540e+05  1.002000e+05   1002.000000     0.000000     0.000000
# 25%    1.742420e+05  3.440500e+05   3436.500000     0.000000     1.000000
# 50%    2.304720e+05  1.054211e+06  10490.000000     0.000000     2.000000
# 75%    4.476520e+05  2.811950e+06  25988.000000     0.000000     3.000000
# max    4.841450e+07  8.209882e+07  42371.000000     1.000000     4.000000
#
#            CONTROL       LOCALE         HBCU          PBI        ANNHI  \
# count  7703.000000  7282.000000  7282.000000  7282.000000  7282.000000
# mean      2.215371    19.620434     0.014282     0.013046     0.004944
# std       0.836528     9.366024     0.118658     0.113479     0.070142
# ...

# %%
column = data['NPT43_PRIV']

# %%
column
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10      16801.0
# 11          NaN
# 12      14178.0
# 13      25406.0
# 14          NaN
# 15          NaN
# 16      21055.0
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23      20057.0
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#          ...
# 7673        NaN
# 7674        NaN
# 7675        NaN
# 7676        NaN
# 7677        NaN
# 7678        NaN
# 7679        NaN
# 7680        NaN
# 7681        NaN
# 7682        NaN
# 7683        NaN
# 7684        NaN
# 7685        NaN
# 7686        NaN
# 7687        NaN
# 7688        NaN
# 7689        NaN
# 7690        NaN
# 7691        NaN
# 7692        NaN
# 7693        NaN
# 7694        NaN
# 7695        NaN
# 7696        NaN
# ...

# %% [markdown]
# #### Standart scoring

# %%
((column - column.mean())/column.std()).plot()

# %%
columnName = 'NPT43_PRIV'

# %%
((data[columnName] - data[columnName].min())/(data[columnName].max() - data[columnName].min())).plot()

# %%
data.columns.values
# Out:
# array(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'INSTURL',
#        'NPCURL', 'HCM2', 'PREDDEG', 'CONTROL', 'LOCALE', 'HBCU', 'PBI',
#        'ANNHI', 'TRIBAL', 'AANAPII', 'HSI', 'NANTI', 'MENONLY',
#        'WOMENONLY', 'RELAFFIL', 'SATVR25', 'SATVR75', 'SATMT25', 'SATMT75',
#        'SATWR25', 'SATWR75', 'SATVRMID', 'SATMTMID', 'SATWRMID', 'ACTCM25',
#        'ACTCM75', 'ACTEN25', 'ACTEN75', 'ACTMT25', 'ACTMT75', 'ACTWR25',
#        'ACTWR75', 'ACTCMMID', 'ACTENMID', 'ACTMTMID', 'ACTWRMID',
#        'SAT_AVG', 'SAT_AVG_ALL', 'PCIP01', 'PCIP03', 'PCIP04', 'PCIP05',
#        'PCIP09', 'PCIP10', 'PCIP11', 'PCIP12', 'PCIP13', 'PCIP14',
#        'PCIP15', 'PCIP16', 'PCIP19', 'PCIP22', 'PCIP23', 'PCIP24',
#        'PCIP25', 'PCIP26', 'PCIP27', 'PCIP29', 'PCIP30', 'PCIP31',
#        'PCIP38', 'PCIP39', 'PCIP40', 'PCIP41', 'PCIP42', 'PCIP43',
#        'PCIP44', 'PCIP45', 'PCIP46', 'PCIP47', 'PCIP48', 'PCIP49',
# ...

# %%
data['NPT43_PRIV'].corr(data['NPT44_PRIV'])
# Out:
# 0.92873416269312892
